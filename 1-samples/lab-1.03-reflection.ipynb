# %% [markdown]
# # Lab 1.03 - Reflection exercises
#
# ## Basic concepts in research
#
# ### Exercise 1 - Retrieval practice: measurement levels
#
# Measurement levels are an important concept in descriptive statistics because most visualization and analysis techniques depend on this. It is therefore important to know and understand the different measurement levels.
#
# Retrieval practice is a study technique that has been scientifically proven to be effective and which leads to improved learning outcomes (Roediger & Karpicke, 2006).
#
# 1. Take a blank sheet of paper and try to reproduce an overview of all measurement levels without consulting the syllabus or other sources. Describe the specific properties for each measurement level and give some examples.
#
# 2. Take enough time for this (e.g. at least 5 to 10 minutes). Do not immediately look into the syllabus, but try to remember as much as possible.
#
#     When you are done with this, indicate everything that you have noted so far with an (e.g. green) marker.
#
#     If possible, consult with a fellow student and try to complete the overview that you have each made. Mark all additions with a marker in a different color (e.g. yellow).
#
# 3. Finally, verify your notes using the syllabus and correct/complete incorrect or missing information if necessary. Indicate this in a third color (e.g. orange or red).
#
# Thanks to the highlighted colors in your notes, you now have an overview of what you already know and what you need to study. Repeat this exercise a number of times during the course of the semester.  Never start by looking at the result of a previous attempt, but immediately try to retrieve as much information as possible from your memory on a blank sheet. Compare the results afterwards. You should notice that over time, you will mark more and more in green and you will use less red or even none at all.

# %% [markdown]
# ## Sampling methods and sampling errors
#
# ### Exercise 2 - sampling methods
#
# A researcher wants to investigate as accurately as possible the consumption habits of residents aged 18 years and up in a certain municipality with 3 residential areas.
# She distinguishes 4 age groups so she eventually has a total of 12 subgroups. From the municipality, she requests the percentual composition of the population in the city, and based on the numbers she calculated the number of respondents required for each age group. We call this type of sample a quota sample.
#
# - Is this a random sample? Why (not)?
#
# It's a random sample. This is a stratified sample.
#
# - Is this sample representative of the population?
#
# It is representative.
#
# - Which types of sampling errors can occur?
#
#
# Still accidental sampling errors can occur (for example: pure coincidence you select only women)
# Accidental non-sampling errors can occur if people give wrong answers by accident
# systematic non-sampling erorr: people lie or under- or overestimate something
#
# - What are the advantages and disadvantages?
#
# Hier worden in de 3 deelgebieden per leeftijdscategorie een bepaald percentage genomen(stratified sample).
#
# Toch kan er nog een systematic sampling error kunnen voorkomen:
# Stel dat de leeftijdscategoriën raar verdeeld zijn vb. alle ouderen in deelgebied A en (bijna) alle 20 tot 40 plussers in deelgebied B. Dit zou ervoor kunnen zorgen dat de verhoudingen leeftijdscategoriën niet meer kloppen.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 3 - sampling methods
#
# A research agency wants to investigate the purchasing behavior of washing products. They interrogate a number of women between 25 and 55 because they assume that these are representative of most customers.
#
# - Is this a random sample? Why (not)?
# Mannen worden uitgesloten, ouderen en jongeren worden ook uitgesloten. Dus zeker niet random.
#
# - Is this sample representative of the population?
# De sample is niet representatief. Niet iedereen van de populatie heeft evenveel kans om gekozen te worden.
#
# - Which sampling error(s) was (were) made?
# Systematic sampling error: Manier waarop sample is samengesteld is fout.
# Er kunnen ook systematic non-sampling errors, accidental sampling errors & accidental non-sampling errors optreden.
#
# - What improvements would you suggest for the way this sample is constructed?
# Mannen toevoegen en leeftijdscategorie uitbreiden.

# %% [markdown]
# ### Exercise 4 - sampling methods
#
# The trade union wants to investigate the working conditions of the employees of an IT company. This company has a total of 3200 employees spread over 12 branch offices.
# Because the total number of employees is quite large, 40 employees are selected at random from each branch office. The size of the sample is, therefore, n = 480.
#
# - Is this a random sample? Why (not)?
# Nee, want niet elke branch heeft evenveel werknemers. bijv. HR heeft niet evenveel werknemers als de developers. niet elk element van de populatie heeft evenveel kans om gekozen te worden.
#
# - Is the sample representative of the population? If not, when could it be representative?
# Nee, niet representatief.
#
# - What kind of error(s) is/are being made here?
# Systematic samplic error
#
# - What improvements would you suggest for the way this sample is constructed?
# Van elk departement éénzelfde percentage vragen.

# %% [markdown]
# ### Exercise 5 - sampling methods
#
# We want to conduct a survey into the quality of our education at Hogeschool Gent. For this purpose, the students present in a certain lecture will be questioned.
#
# - Is this a random sample? Why (not)?
# Nee, want slechts studenten die komen opdagen en in een bepaalde richting zitten zullen bevraagd worden.
# - Is the sample representative of the population?
# Nee
#
# - What kind of error(s) is/are being made here?
# Systematic sampling error: onze sample is gebaseerd enkel op de mensen die deelnemen aan de les
# (accidental sampling (toeval)& non-sampling (verkeerd lezen van de vragen) & systematic non-sampling (liegen) kan ook altijd)
#
# - Suppose the lecturer who teaches the subject is present during the questioning. What influence can this have and what mistake is made in this case?
# Ja, afhankelijk van hoe sterk deze aanwezig is, zullen studenten positiever antwoorden door sociale controle.
#
# - Suppose the questioning is not held during a lecture but after an exam. What mistake can be made then?
# Mensen zullen misschien random antwoorden om sneller door te gaan.
#
# - What improvements would you suggest for the way this sample is constructed?
# Verplicht enquête laten invullen vooraleer een student kan doorgaan op Chamilo.

# %% [markdown]
# ### Exercise 6 - Retrieval practice: sampling errors
#
# Use the procedure for retrieval practice from Exercise 1 to study the types of sampling errors. List the different sampling errors, describe each and give an example.

# %% [markdown]
# ## Exercise 7
#
# What is the measurement level of each of these variables:
#
# 1. an employee's position (executive, managerial, ...)
# 2. the employee's salary
# 3. the name of the employee's department
# 4. the employee's seniority (= the number of years of service)
#
# **Solution**
#
# | Variable | Kwalitatief/kwantitatief | nomainaal/ordinaal/ratio/interval
# |--|--|--
# | 1. an employee's position (executive, managerial, ...) | Kwalitatief  | ordinaal
# | 2. the employee's salary | kwantitatief  | ratio
# | 3. the name of the employee's department | Kwalitatief  | nonimaal
# | 4. the employee's seniority (= the number of years of service) | kwantitatief  | ratio

# %% [markdown]
# ## Exercise 8
#
# The Flemish government wants to survey the social well-being of its residents. It therefore lets a computer randomly choose mobile phone numbers from a database containing all known mobile phone numbers of Flemings. When someone does not respond, it calls back repeatedly until there is an answer or until a maximum number of attempts is reached.
#
# 1. Is this a random sample? Explain.
# 2. What type of error(s) is made here?
# 3. Is this a good sample? Explain.
#
# 1. Is this a random sample? Explain.
# Nee, want mensen zonder gsm worden uitgesloten, mensen die geen zin hebben om te antwoorden ook niet.
# 2. What type of error(s) is made here?
# Systematische sampling error.
# 3. Is this a good sample? Explain.

# %% [markdown]
# ## Exercise 9
#
# What is the measurement level of each of these variables:
#
# 1. the cattle breed of a cow (Jersey, Holstein, Belgisch witblauw, Limousin...)
# 2. the weight of a cow
# 3. the number of liters of milk a cow produces in a year
# 4. life stage of a cow (calf, heifer (= one-year-old calf), heifer, cow)
#
# **Solution**
#
# | Variable | Kwalitatief/kwantitatief | nomainaal/ordinaal/ratio/interval
# |--|--|--
# | 1. the cattle breed of a cow (Jersey, Holstein, Belgisch witblauw, Limousin...) | kwalitatief | nominaal
# | 2. the weight of a cow | kwantitatief | ratio
# | 3. the number of liters of milk a cow produces in a year | kantitatief | ratio
# | 4. life stage of a cow (calf, heifer (= one-year-old calf), heifer, cow) | kwalitatief | ordinaal

# %% [markdown]
# ## Examenvragen augustus
#
# Wat is het meetniveau van elk van deze variabelen
#
# 1. de tijd waarin een langeafstandsloper 20km loopt in een wedstrijd
# 2. het rugnummer dat de langeafstandsloper krijgt opgespeld tijdens de wedstrijd
# 3. de plaats in de uiteindelijke rangschikking waarop de langeafstandsloper eindigt
# 4. de medialle die de langeafstandsloper eventueel behaalde: goud, zilver of brons
#
# | Variable | Kwalitatief/kwantitatief | nomainaal/ordinaal/ratio/interval
# |--|--|--
# | 1. de tijd waarin een langeafstandsloper 20km loopt in een wedstrijd | Kwantitatief | ratio
# | 2. het rugnummer dat de langeafstandsloper krijgt opgespeld tijdens de wedstrijd | Kwalitatief | nominaal
# | 3. de plaats in de uiteindelijke rangschikking waarop de langeafstandsloper eindigt | Kwalitatief | Ordinaal
# | 4. de medialle die de langeafstandsloper eventueel behaalde: goud, zilver of brons | Kwalitatief | ordinaal
#
#
# Een artikel "Hoge niveaus van kwik zijn gevonden bij inwoners van Californië" beschrijft een onderzoek waarin haarstalen werden getest op kwik. De haarstalen werden verkregen van meer dan 6000 mensen die vrijwillig haarstalen opstuurden naar onderzoekers van Greenpeace en de Sierra Club. De onderzoekers ondekten dat bijna een derde van de geteste mensen kwikgehaltes had die hoger waren dan de concentratie veilig te zijn.
#
# 1. Is dit een random sample? Leg uit.
# 2. Welk type fout(en) wordt hier gemaakt?
# 3. Is dit een goede sample? Leg uit.
#
#
# 1. Is dit een random sample? Leg uit.
#
# Heeft elk element van de populatie evenveel kans om deel uit te maken van de populatie? Nee, geen random sample, aangezien enkel mensen die vrijwillig willen meedoen, deel uit maken van de sample.
#
# 2. Welk type fout(en) wordt hier gemaakt?
#
# Dit een vrijwillig onderzoek en dus een systematische sampling error (Systematic Sampling Error).
#
# 3. Is dit een goede sample? Leg uit.
#
# Nee, enkel de mensen die interesse (& tijd) hebben zullen zich vrijmaken voor dit onderwerp.
